# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display charts inside the notebook
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv("dataset/retail_sales_dataset.csv")
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df["Product Category"].unique()
# Out:
# array(['Beauty', 'Clothing', 'Electronics'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Product Category")
plt.title("Number of Sales by Product Category")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Gender")
plt.title("Sales Distribution by Gender")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=10, kde=True)
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.show()

# %%
plt.figure(figsize=(8,5))

sales = df.groupby("Product Category")["Total Amount"].sum()

sales.plot(kind="bar")

plt.title("Total Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.show()

# %%
plt.figure(figsize=(8,5))

avg = df.groupby("Product Category")["Total Amount"].mean()

avg.plot(kind="bar", color="green")

plt.title("Average Purchase Amount")
plt.ylabel("Average Amount")
plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Month"] = df["Date"].dt.month_name()

# %%
monthly_sales = df.groupby("Month")["Total Amount"].sum()

plt.figure(figsize=(12,5))
monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid(True)
plt.show()

# %%
top_customers = df.groupby("Customer ID")["Total Amount"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_customers.plot(kind="bar")

plt.title("Top 10 Customers by Spending")
plt.xlabel("Customer ID")
plt.ylabel("Total Amount")
plt.show()

# %%
quantity = df.groupby("Product Category")["Quantity"].sum()

plt.figure(figsize=(8,5))
quantity.plot(kind="bar", color="orange")

plt.title("Total Quantity Sold by Product Category")
plt.ylabel("Quantity Sold")
plt.show()

# %%
plt.figure(figsize=(6,5))

numeric_df = df.select_dtypes(include=["number"])

sns.heatmap(numeric_df.corr(), annot=True, cmap="Blues")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Key Insights
#
# - The dataset contains 1000 retail transactions.
# - No missing values were found.
# - Clothing had the highest number of transactions.
# - Sales were distributed across Beauty, Clothing, and Electronics.
# - Customer ages varied widely, with most customers in the adult age group.
# - The heatmap helped identify relationships between numerical features such as Quantity, Price per Unit, and Total Amount.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Total Amount"], bins=20, kde=True)

plt.title("Distribution of Total Purchase Amount")
plt.xlabel("Total Amount")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.barplot(data=df, x="Gender", y="Quantity")

plt.title("Average Quantity Purchased by Gender")

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(y=df["Total Amount"])

plt.title("Box Plot of Total Purchase Amount")

plt.show()

# %% [markdown]
# # Conclusion
#
# This project performed Exploratory Data Analysis (EDA) on a retail sales dataset containing 1000 transactions. The dataset was clean and contained no missing values. Various visualizations were created to understand customer demographics, product performance, sales trends, and purchasing behavior.
#
# The analysis showed differences in sales across product categories and customer groups. The insights gained from this project can help businesses understand customer preferences and make better decisions regarding inventory, marketing, and sales strategies

# %% [markdown]
# # Retail Sales Data - Exploratory Data Analysis (EDA)
#
# **Intern:** Betson George Abraham
# **Internship:** Oasis Infobyte - Data Analytics Internship
# **Task:** EDA on Retail Sales Dataset

# %% [markdown]
# ## Objective
#
# The objective of this project is to perform Exploratory Data Analysis (EDA) on a retail sales dataset to understand customer purchasing behavior, product performance, and sales trends using Python and data visualization libraries.

# %% [markdown]
# ## Import Required Libraries

# %% [markdown]
# ## Load the Dataset

# %% [markdown]
# ## Explore the Dataset

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# The dataset was checked for missing values and data types. No missing values were found, so no cleaning was required.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Key Insights
#
# - The dataset contains 1000 retail transactions.
# - No missing values were found.
# - Clothing recorded the highest number of transactions.
# - Customer purchasing patterns varied across product categories.
# - Sales analysis provides useful business insights for inventory and marketing decisions.

# %% [markdown]
# ## Conclusion
#
# The project successfully analyzed retail sales data using Python, Pandas, Matplotlib, and Seaborn. The visualizations helped identify customer behavior, product trends, and sales performance, demonstrating how Exploratory Data Analysis can support business decision-making.
